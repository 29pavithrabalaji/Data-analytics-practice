# %%
# Import Packages

import pandas as pd
import googleapiclient.discovery

# %%
# YouTube API Access

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyBsZEq-OroOTz7Qc_EMLkuqT37reP3nFBw"

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
# Function to get video ids from a given playlist

def youtube_videoid(playlist):
    videolist=[]
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId='your_playlistid',maxResults=50
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
                  
        videolist.append(response['items'][i]['contentDetails']['videoId'])
        
    nextpagetoken=response.get('nextPageToken') 
    extra_pages_is_there=True
    
    while extra_pages_is_there:
        if nextpagetoken is None:
            extra_pages_is_there=False
            
        else:
            request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId='your_playlistid',maxResults=50,pageToken=nextpagetoken
    )
            response = request.execute()
            
            for i in  range(len(response['items'])):
                
                videolist.append(response['items'][i]['contentDetails']['videoId'])
                
            nextpagetoken=response.get('nextPageToken')    
        
            
      
        
            
            
    return videolist

# %%
type(response['items'][0]['contentDetails']['videoId'])
# Out:
# str

# %%
len(response['items'])
# Out:
# 1

# %%
# Finding length of function output

len(youtube_videoid(playlistid))
# Out:
# 20

# %%
# Running function for given playlist id
youtube_videoid(playlistid)
# Out:
# ['TIikBT-KQaY',
#  'PLW1EA-Q78Q',
#  'SmxRR60zoqQ',
#  'xpXxB7AmvuE',
#  'REKGK9dGwg0',
#  'UpSRR0AOxbQ',
#  '4Y49XfDxpx0',
#  'zgbWdxPV_fM',
#  'Yn-s4K-QuBk',
#  'VLmo0t7S9tI',
#  'oHq4PQtO0kI',
#  'qFYVDb8AmFI',
#  'PV3zeuooi_I',
#  'knTyThuNxmY',
#  'BezUXpQUpUI',
#  'DVW8WKH0JSQ',
#  'AKSZua0zC5E',
#  'ius1JlNaqbE',
#  'kpZUOQhjA0U',
#  'WCflNfPp2fo']

# %%
videoinfo=youtube_videoid(playlistid)

# %%
videoinfo
# Out:
# ['TIikBT-KQaY',
#  'PLW1EA-Q78Q',
#  'SmxRR60zoqQ',
#  'xpXxB7AmvuE',
#  'REKGK9dGwg0',
#  'UpSRR0AOxbQ',
#  '4Y49XfDxpx0',
#  'zgbWdxPV_fM',
#  'Yn-s4K-QuBk',
#  'VLmo0t7S9tI',
#  'oHq4PQtO0kI',
#  'qFYVDb8AmFI',
#  'PV3zeuooi_I',
#  'knTyThuNxmY',
#  'BezUXpQUpUI',
#  'DVW8WKH0JSQ',
#  'AKSZua0zC5E',
#  'ius1JlNaqbE',
#  'kpZUOQhjA0U',
#  'WCflNfPp2fo']

# %%
# Function to get video details using video ids

def videodetails(videoinfo):
    videodetails=[]
    for i in range(0,len(videoinfo),50):
        request = youtube.videos().list(
        part="snippet,statistics",
        id=','.join(videoinfo[i:i+50])
    )
        response = request.execute() 
        
        for i in range(len(response['items'])):
            videodata=dict(title_name=response['items'][i]['snippet']['title'],
                          publishing_date=response['items'][i]['snippet']['publishedAt'],
                          views=response['items'][i]['statistics']['viewCount'],
                          comments=response['items'][i]['statistics']['commentCount'],
                          likes=response['items'][i]['statistics']['likeCount'])
            
            videodetails.append(videodata)
            
        
        

        
    


    return videodetails

# %%
# Running function for given video ids

finaldata=videodetails(videoinfo)

# %%
# Dataframe of video details

finalinfo=pd.DataFrame(finaldata)

# %%
# Video details Information

finalinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title_name       20 non-null     object
#  1   publishing_date  20 non-null     object
#  2   views            20 non-null     object
#  3   comments         20 non-null     object
#  4   likes            20 non-null     object
# dtypes: object(5)
# memory usage: 932.0+ bytes

# %%
# Converting columns to integer datatype
finalinfo['views']=pd.to_numeric(finalinfo['views'])
finalinfo['comments']=pd.to_numeric(finalinfo['comments'])
finalinfo['likes']=pd.to_numeric(finalinfo['likes'])

# %%
# Converting date to datetime from object

finalinfo['publishing_date']=pd.to_datetime(finalinfo['publishing_date'])

# %%
# Creating new columns for month,year

finalinfo['month']=finalinfo['publishing_date'].dt.month
finalinfo['year']=finalinfo['publishing_date'].dt.year

# %%
# Creating new columns for yearmonth

finalinfo['yearmonth']=finalinfo['month'].astype(str)+"-"+finalinfo['year'].astype(str)

# %%
# Sorting top 10 videos by views
finalinfo.sort_values(by='views',ascending=False).head(20)
# Out:
#                                            title_name  \
# 0                   Chandramukhi Real History | Tamil
# 1      Nun Real Story Explained | Tamil | Madan Gowri
# 2        Real Aayirathil Oruvan | Tamil | Madan Gowri
# 3         ADIPURUSH - Insulting Gods?! 😡| Madan Gowri
# 4     History of Cleopatra | Tamil | Madan Gowri | MG
# 5   Real Ratsasan | Tamil | Alexander Spesivtsev |...
# 6   Annabelle | Tamil | Real Ghost Story | Madan G...
# 7   Unstoppable Indian | Tamil | Air Deccan Gopina...
# 8         KGF Gold Mystery | Tamil | Madan Gowri | MG
# 9   😱 Maamannan  - Fahadh Faasil Issue 🔥 | Madan G...
# 10                Alexander The Great History | Tamil
# 11  Bodhidharman China Explained | Tamil | Madan G...
# 12  Iron Man Story | Tamil | Robert Downey Jr | Ma...
# 13                        1 Girl vs 1 Country | Tamil
# 14  2.0 Your Aura Explained | Tamil | Madan Gowri ...
# 15     Ashoka The Great History | Tamil | Madan Gowri
# 16  Joker Motivation History | Tamil | Joaquin Pho...
# 17                     Asuran Untold  Secrets | Tamil
# 18  Real Jailer 🚨 God Statues Issue 🥷Explained | M...
# 19       💥 Oppenheimer 🔥 Real 😱 History | Madan Gowri
#
#              publishing_date    views  comments  likes  month  year yearmonth
# 0  2019-08-21 12:55:53+00:00  2772751      6013  75791      8  2019    8-2019
# 1  2020-01-17 09:00:03+00:00  1725316      6428  65874      1  2020    1-2020
# 2  2020-02-29 07:55:17+00:00  1454227      4890  71084      2  2020    2-2020
# 3  2023-06-21 15:14:08+00:00  1402277      2872  44521      6  2023    6-2023
# 4  2017-09-25 13:01:46+00:00  1359622      1710  37670      9  2017    9-2017
# 5  2018-11-11 09:17:32+00:00  1309114      4477  40314     11  2018   11-2018
# 6  2018-11-03 08:34:40+00:00  1286254      4757  41155     11  2018   11-2018
# 7  2020-01-13 12:26:10+00:00  1254705      4531  58998      1  2020    1-2020
# 8  2019-02-10 11:32:48+00:00  1198257      5701  47313      2  2019    2-2019
# 9  2023-08-04 14:06:51+00:00  1033007      3070  36650      8  2023    8-2023
# 10 2019-11-21 11:01:39+00:00  1000312      3890  41131     11  2019   11-2019
# 11 2020-02-04 11:28:03+00:00   982987      2609  41876      2  2020    2-2020
# 12 2019-01-28 11:02:42+00:00   960860      9395  60121      1  2019    1-2019
# 13 2019-11-12 12:38:10+00:00   824150      3449  29359     11  2019   11-2019
# 14 2018-12-02 09:18:30+00:00   742661      3966  33100     12  2018   12-2018
# 15 2020-01-25 07:53:27+00:00   724515      2542  28357      1  2020    1-2020
# 16 2019-10-21 12:20:08+00:00   639204      3511  37275     10  2019   10-2019
# 17 2019-10-08 12:39:00+00:00   587929      2677  26166     10  2019   10-2019
# 18 2023-08-11 14:44:53+00:00   554546       694  18401      8  2023    8-2023
# 19 2023-07-24 16:53:38+00:00   442388       668  16400      7  2023    7-2023
